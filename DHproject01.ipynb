# %%
import pandas as pd
df = pd.read_csv('steel_date.csv')

# %%
steel = df.copy()

# %%
steel.head()
# Out:
#    Unnamed: 0  PLATE_NO         ROLLING_DATE SCALE        SPEC STEEL_KIND  \
# 0           0  PB562774  2008-08-01:00:00:15    양품  AB/EH32-TM         T1
# 1           1  PB562775  2008-08-01:00:00:16    양품  AB/EH32-TM         T1
# 2           2  PB562776  2008-08-01:00:00:59    양품   NV-E36-TM         T8
# 3           3  PB562777  2008-08-01:00:01:24    양품   NV-E36-TM         T8
# 4           4  PB562778  2008-08-01:00:01:44    양품  BV-EH36-TM         T8
#
#    PT_THK  PT_WDTH  PT_LTH  PT_WGT  ... FUR_HZ_TEMP  FUR_HZ_TIME  FUR_SZ_TEMP  \
# 0   32.25     3707   15109   14180  ...        1144          116         1133
# 1   32.25     3707   15109   14180  ...        1144          122         1135
# 2   33.27     3619   19181   18130  ...        1129          116         1121
# 3   33.27     3619   19181   18130  ...        1152          125         1127
# 4   38.33     3098   13334   12430  ...        1140          134         1128
#
# ...

# %%
# 필요없는 칼럼 삭제
steel_d = steel.drop([ 'FUR_HZ_TEMP', 'FUR_HZ_TIME' , 'FUR_SZ_TEMP','FUR_SZ_TIME',
                     'FUR_NO_ROW', 'FUR_TIME' , 'FUR_EXTEMP', 'ROLLING_TEMP_T5', 'ROLLING_DESCALING'], axis = 1)
steel_d
# Out:
#      Unnamed: 0  PLATE_NO         ROLLING_DATE  SCALE        SPEC STEEL_KIND  \
# 0             0  PB562774  2008-08-01:00:00:15      1  AB/EH32-TM         T1
# 1             1  PB562775  2008-08-01:00:00:16      1  AB/EH32-TM         T1
# 2             2  PB562776  2008-08-01:00:00:59      1   NV-E36-TM         T8
# 3             3  PB562777  2008-08-01:00:01:24      1   NV-E36-TM         T8
# 4             4  PB562778  2008-08-01:00:01:44      1  BV-EH36-TM         T8
# ..          ...       ...                  ...    ...         ...        ...
# 715         715  PB563502  2008-08-02:13:35:36      0       NK-KA         C0
# 716         716  PB563503  2008-08-02:13:35:02      1      NV-A32         C0
# 717         717  PB563504  2008-08-02:14:40:00      1      NV-A32         C0
# 718         718  PB563505  2008-08-02:13:35:19      1        LR-A         C0
# 719         719  PB563506  2008-08-02:14:40:53      1      GL-A32         C0
#
# ...

# %%
steel_d.isnull().sum() # 결측치확인
# Out:
# Unnamed: 0      0
# ROLLING_DATE    0
# SCALE           0
# SPEC            0
# STEEL_KIND      0
# PT_THK          0
# PT_WDTH         0
# PT_LTH          0
# PT_WGT          0
# FUR_NO          0
# HSB             0
# WORK_GR         0
# dtype: int64

# %%
steel_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    720 non-null    int64
#  1   ROLLING_DATE  720 non-null    object
#  2   SCALE         720 non-null    object
#  3   SPEC          720 non-null    object
#  4   STEEL_KIND    720 non-null    object
#  5   PT_THK        720 non-null    float64
#  6   PT_WDTH       720 non-null    int64
#  7   PT_LTH        720 non-null    int64
#  8   PT_WGT        720 non-null    int64
#  9   FUR_NO        720 non-null    object
#  10  HSB           720 non-null    object
#  11  WORK_GR       720 non-null    object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 67.6+ KB

# %%
#steel_d['ROLLING_DATE'] = pd.to_datetime(steel_d['ROLLING_DATE']) 시간변경실패

# %%
#dfw2 = steel_d.groupby(['WORK_GR', 'SCALE'], as_index = False).agg(count = ('PLATE_NO', 'count'))

#dfw2
#카운트로 정렬했을때는 결과값이 똑같았음

# %%
dfw = steel.groupby(['WORK_GR', 'SCALE'], as_index = False).agg(count = ('SPEC', 'count'))

dfw
# Out:
#   WORK_GR SCALE  count
# 0      1조    불량     67
# 1      1조    양품    122
# 2      2조    불량     45
# 3      2조    양품    120
# 4      3조    불량     54
# 5      3조    양품    118
# 6      4조    불량     65
# 7      4조    양품    129

# %%
steel['SCALE'] = steel['SCALE'].replace({'양품':1, '불량':0})
steel['HSB'] = steel['HSB'].replace({'적용':1, '미적용':0})

# %%
dfw = steel.groupby(['WORK_GR', 'SCALE'], as_index = False).agg(count = ('SPEC', 'count'))

dfw
# Out:
#   WORK_GR  SCALE  count
# 0      1조      0     67
# 1      1조      1    122
# 2      2조      0     45
# 3      2조      1    120
# 4      3조      0     54
# 5      3조      1    118
# 6      4조      0     65
# 7      4조      1    129
